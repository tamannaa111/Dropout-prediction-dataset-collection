# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/MyDrive/DropoutTamanna.csv')

# %%
df.head()
# Out:
#   marital status  Family income level Class attendance    average CGPA  \
# 0        Married  35,000 - 50,000 BDT    More than 50%  More than 3.50
# 1      Unmarried  35,000 - 50,000 BDT    More than 50%  More than 3.50
# 2      Unmarried  15,000 - 35,000 BDT    More than 50%  More than 3.50
# 3        Married     Above 50,000 BDT    More than 50%     3.00 - 3.50
# 4        Married  35,000 - 50,000 BDT    More than 50%  More than 3.50
#
#    Retake course(রিটেক কোর্সের সংখ্যা)  \
# 0                                    0
# 1                                    0
# 2                                    0
# 3                                    0
# 4                                    0
#
#                              idea about the course Scholarship financial aid  \
# 0                   Limited Knowledge(সীমিত জ্ঞান)         Yes            No
# 1                   Limited Knowledge(সীমিত জ্ঞান)         Yes            No
# ...

# %%
new_column_names = {
    'marital status': 'MS',
    'Family income level': 'FIS',
    'Class attendance': 'CSR',
    'average CGPA': 'ACG',
    'Retake course(রিটেক কোর্সের সংখ্যা)': 'NRC',
    'idea about the course': 'IDAC',
    'Scholarship': 'S/W',
    'financial aid': 'EFA',
    'course selection': 'CS',
    'academic difficulties': 'AD',
    'challenges ': 'Ch',
    'university provided adequate support': 'universitySupport',
    'victim of bullying or ragging ': 'agging'
}

df.rename(columns=new_column_names, inplace=True)

df.head()
# Out:
#           MS                  FIS            CSR             ACG  NRC  \
# 0    Married  35,000 - 50,000 BDT  More than 50%  More than 3.50    0
# 1  Unmarried  35,000 - 50,000 BDT  More than 50%  More than 3.50    0
# 2  Unmarried  15,000 - 35,000 BDT  More than 50%  More than 3.50    0
# 3    Married     Above 50,000 BDT  More than 50%     3.00 - 3.50    0
# 4    Married  35,000 - 50,000 BDT  More than 50%  More than 3.50    0
#
#                                               IDAC  S/W  EFA  \
# 0                   Limited Knowledge(সীমিত জ্ঞান)  Yes   No
# 1                   Limited Knowledge(সীমিত জ্ঞান)  Yes   No
# 2  No Prior Knowledgeকোনো পূর্ববর্তী জ্ঞান ছিল না)  Yes  Yes
# 3                   Limited Knowledge(সীমিত জ্ঞান)  Yes   No
# 4                   Limited Knowledge(সীমিত জ্ঞান)  Yes   No
#
#                        CS   AD  ... financial crisis  \
# 0               Satisfied  Yes  ...               No
# 1     Extremely Satisfied   No  ...               No
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   MS                             313 non-null    object
#  1   FIS                            313 non-null    object
#  2   CSR                            313 non-null    object
#  3   ACG                            313 non-null    object
#  4   NRC                            313 non-null    int64
#  5   IDAC                           313 non-null    object
#  6   S/W                            313 non-null    object
#  7   EFA                            313 non-null    object
#  8   CS                             313 non-null    object
#  9   AD                             313 non-null    object
#  10  challenges                     313 non-null    object
#  11  physical and mental            313 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# MS                               0
# FIS                              0
# CSR                              0
# ACG                              0
# NRC                              0
# IDAC                             0
# S/W                              0
# EFA                              0
# CS                               0
# AD                               0
# challenges                       0
# physical and mental              0
# financial crisis                 0
# financial situation              0
# universitySupport                0
# love to study                    1
# victim of bullying or ragging    0
# relationship problems            0
# quizzes                          1
# improvement                      8
# engaged in any work              0
# Target Column                    0
# dtype: int64

# %%
import math
modeTestScore1=(df['love to study'].mode()[0])
modeTestScore2=(df['quizzes'].mode()[0])




df['quizzes']=df['quizzes'].fillna(modeTestScore2)
df['love to study']=df['love to study'].fillna(modeTestScore1)

# %%
df.isnull().sum()
# Out:
# MS                               0
# FIS                              0
# CSR                              0
# ACG                              0
# NRC                              0
# IDAC                             0
# S/W                              0
# EFA                              0
# CS                               0
# AD                               0
# challenges                       0
# physical and mental              0
# financial crisis                 0
# financial situation              0
# universitySupport                0
# love to study                    0
# victim of bullying or ragging    0
# relationship problems            0
# quizzes                          0
# improvement                      8
# engaged in any work              0
# Target Column                    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   MS                             313 non-null    object
#  1   FIS                            313 non-null    object
#  2   CSR                            313 non-null    object
#  3   ACG                            313 non-null    object
#  4   NRC                            313 non-null    int64
#  5   IDAC                           313 non-null    object
#  6   S/W                            313 non-null    object
#  7   EFA                            313 non-null    object
#  8   CS                             313 non-null    object
#  9   AD                             313 non-null    object
#  10  challenges                     313 non-null    object
#  11  physical and mental            313 non-null    object
# ...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()

categorical_columns = [
    'MS', 'FIS', 'CSR', 'ACG', 'IDAC', 'S/W ',
    'EFA ', 'CS', 'AD',
    'challenges ', 'physical and mental', 'financial crisis  ',
    'financial situation', 'universitySupport ', 'love to study' ,
    'victim of bullying or ragging ', 'relationship problems ',
     'engaged in any work  '
]

for column in categorical_columns:
    df[column] = label_encoder.fit_transform(df[column])

df.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3652         try:
# -> 3653             return self._engine.get_loc(casted_key)
#    3654         except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'S/W '
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# List of categorical columns
categorical_columns = [
    'MS', 'FIS', 'CSR', 'ACG', 'IDAC', 'S/W ',
    'EFA ', 'CS', 'AD',
    'challenges ', 'physical and mental', 'financial crisis  ',
    'financial situation', 'universitySupport ', 'love to study' ,
    'victim of bullying or ragging ', 'relationship problems ',
    'engaged in any work  '
]

# Remove leading and trailing spaces from column names
df.columns = df.columns.str.strip()
categorical_columns = [col.strip() for col in categorical_columns]

# Encode categorical features
for column in categorical_columns:
    if column in df.columns:  # Ensure the column exists in the dataframe
        label_encoder = LabelEncoder()  # Instantiate a new LabelEncoder for each column
        df[column] = label_encoder.fit_transform(df[column])

# Display the first few rows of the encoded dataframe
print(df.head())
# Out:
#    MS  FIS  CSR  ACG  NRC  IDAC  S/W  EFA  CS  AD  ...  financial crisis  \
# 0   0    1    3    3    0     1    3    0   4   2  ...                 1
# 1   1    1    3    3    0     1    3    0   2   1  ...                 1
# 2   1    0    3    3    0     2    3    1   1   2  ...                 2
# 3   0    2    3    1    0     1    3    0   4   1  ...                 1
# 4   0    1    3    3    0     1    3    0   4   2  ...                 1
#
#    financial situation  universitySupport  love to study  \
# 0                    0                  2              0
# 1                    1                  2              2
# 2                    3                  1              1
# 3                    1                  1              0
# 4                    4                  2              0
#
#    victim of bullying or ragging  relationship problems  quizzes  improvement  \
# 0                              1                      1      3.0          1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 313 entries, 0 to 312
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   MS                             313 non-null    int64
#  1   FIS                            313 non-null    int64
#  2   CSR                            313 non-null    int64
#  3   ACG                            313 non-null    int64
#  4   NRC                            313 non-null    int64
#  5   IDAC                           313 non-null    int64
#  6   S/W                            313 non-null    int64
#  7   EFA                            313 non-null    int64
#  8   CS                             313 non-null    int64
#  9   AD                             313 non-null    int64
#  10  challenges                     313 non-null    int64
#  11  physical and mental            313 non-null    int64
# ...

# %%
df.head()
# Out:
#    MS  FIS  CSR  ACG  NRC  IDAC  S/W  EFA  CS  AD  ...  financial crisis  \
# 0   0    1    3    3    0     1    3    0   4   2  ...                 1
# 1   1    1    3    3    0     1    3    0   2   1  ...                 1
# 2   1    0    3    3    0     2    3    1   1   2  ...                 2
# 3   0    2    3    1    0     1    3    0   4   1  ...                 1
# 4   0    1    3    3    0     1    3    0   4   2  ...                 1
#
#    financial situation  universitySupport  love to study  \
# 0                    0                  2              0
# 1                    1                  2              2
# 2                    3                  1              1
# 3                    1                  1              0
# 4                    4                  2              0
#
#    victim of bullying or ragging  relationship problems  quizzes  improvement  \
# 0                              1                      1      3.0          1.0
# ...

# %%
df.describe()
# Out:
#                MS         FIS         CSR         ACG         NRC        IDAC  \
# count  313.000000  313.000000  313.000000  313.000000  313.000000  313.000000
# mean     0.798722    1.153355    3.744409    1.760383    0.607029    1.194888
# std      0.401597    0.984884    1.600834    1.287301    1.511351    0.563619
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000    0.000000    3.000000    1.000000    0.000000    1.000000
# 50%      1.000000    1.000000    5.000000    1.000000    0.000000    1.000000
# 75%      1.000000    2.000000    5.000000    3.000000    0.000000    2.000000
# max      1.000000    3.000000    5.000000    4.000000   18.000000    2.000000
#
#               S/W         EFA          CS          AD  ...  financial crisis  \
# count  313.000000  313.000000  313.000000  313.000000  ...        313.000000
# mean     2.325879    0.488818    2.578275    1.226837  ...          1.204473
# ...

# %%
df.corr()
# Out:
#                                      MS       FIS       CSR       ACG  \
# MS                             1.000000  0.167428  0.168997  0.024205
# FIS                            0.167428  1.000000  0.053401 -0.006316
# CSR                            0.168997  0.053401  1.000000  0.245477
# ACG                            0.024205 -0.006316  0.245477  1.000000
# NRC                           -0.035683  0.047076 -0.231086 -0.214941
# IDAC                           0.003936 -0.007822 -0.079604 -0.120967
# S/W                            0.025430 -0.039513  0.060686  0.136199
# EFA                           -0.098902 -0.113509 -0.047565 -0.031521
# CS                             0.040584  0.033944  0.204494  0.106262
# AD                            -0.173466  0.005346 -0.147489 -0.132399
# challenges                    -0.135441 -0.023733 -0.077520 -0.065250
# physical and mental           -0.147835 -0.024919 -0.153587 -0.118964
# ...

# %%
plt.figure(figsize=(8, 8))
sns.histplot(data=df, kde=True)
plt.title("Histogram of DataFrame")
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=df, orient='h')
plt.title("Box Plot of DataFrame")
plt.show()

# %%
plt.figure(figsize=(20, 6))
ax = df.describe().loc[['mean', 'std', '25%', '50%', '75%', 'max']].plot(kind='bar', legend=False)
plt.title("Bar Plot of Mean, Std, Min, Max")
plt.ylabel("Values")

ax.set_xticklabels(['Mean', 'Std', '25%', '50%', '75%', 'Max'], rotation=0)

plt.show()

# %%
df.shape
# Out:
# (313, 22)

# %%
plt.figure(figsize=(18,12))
sns.heatmap(df.corr(),annot=True,fmt='.2f')
# Out:
# <Axes: >

# %%
import pandas as pd
from sklearn.feature_selection import SelectKBest, chi2
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer



# Separate numeric and categorical columns
numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
categorical_columns = df.select_dtypes(include=['object']).columns

# Encode categorical features
encoder = LabelEncoder()
for col in categorical_columns:
    df[col] = encoder.fit_transform(df[col])

# Define the target and features
X_numeric = df[numeric_columns].drop(columns=['Target Column'])
y = df['Target Column']

# Handle missing values
imputer = SimpleImputer(strategy='mean')
X_numeric_imputed = imputer.fit_transform(X_numeric)

# Feature selection
selector = SelectKBest(score_func=chi2, k=5)
X_numeric_new = selector.fit_transform(X_numeric_imputed, y)

# Get the selected feature indices
selected_indices = selector.get_support(indices=True)

# Get the selected feature names
selected_features = X_numeric.columns[selected_indices]
print("Selected Features:")
print(selected_features)
# Out:
# Selected Features:
# Index(['NRC', 'EFA', 'CS', 'financial crisis', 'improvement'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_numeric_new, y, test_size=0.11, random_state=42)

print("Training data shape (X_train, y_train):", X_train.shape, y_train.shape)
print("Testing data shape (X_test, y_test):", X_test.shape, y_test.shape)
# Out:
# Training data shape (X_train, y_train): (278, 5) (278,)
# Testing data shape (X_test, y_test): (35, 5) (35,)

# %%
from sklearn.naive_bayes import GaussianNB

model = GaussianNB()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = np.sum(y_pred == y_test) / len(y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9714285714285714

# %%
cm = np.array(pd.crosstab(y_test, y_pred))
sns.heatmap(cm, annot=True, fmt=".2f")
plt.xlabel("True Label")
plt.ylabel("Predicted Label")
plt.title("Confusion Matrix for Naive Bayes Classifier")
plt.show()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        23
#            1       0.92      1.00      0.96        12
#
#     accuracy                           0.97        35
#    macro avg       0.96      0.98      0.97        35
# weighted avg       0.97      0.97      0.97        35

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
print(classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9428571428571428
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        23
#            1       0.92      0.92      0.92        12
#
#     accuracy                           0.94        35
#    macro avg       0.94      0.94      0.94        35
# weighted avg       0.94      0.94      0.94        35

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)
y_pred = knn.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9714285714285714

# %%
cm = np.array(pd.crosstab(y_test, y_pred))
sns.heatmap(cm, annot=True, fmt=".2f")
plt.xlabel("True Label")
plt.ylabel("Predicted Label")
plt.title("Confusion Matrix for KNN Classifier")
plt.show()

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

accuracy = np.sum(y_pred == y_test) / len(y_test)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.9428571428571428

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print("MAE:", mae)
print("MSE:", mse)
print("R^2:", r2)
# Out:
# MAE: 0.20854125863972947
# MSE: 0.06593748669953951
# R^2: 0.7073426767864641

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(X_train,y_train)
y_pred=rf.predict(X_test)
accuracy_rf=accuracy_score(y_test,y_pred)
print(f'Accuracy of RandomForestClassifier is {accuracy_rf*100:.2f}%')
# Out:
# Accuracy of RandomForestClassifier is 97.14%

# %%
from sklearn.tree import DecisionTreeClassifier
dt_classifier = DecisionTreeClassifier()
dt_classifier.fit(X_train, y_train)
dt_pred = dt_classifier.predict(X_test)
dt_accuracy = accuracy_score(y_test, dt_pred)
print(f"Decision Tree Accuracy: {dt_accuracy*100:.2f}%")
# Out:
# Decision Tree Accuracy: 94.29%

# %%
# Naive Bayes Classifier (Gaussian)
nb_classifier = GaussianNB()
nb_classifier.fit(X_train, y_train)
nb_pred = nb_classifier.predict(X_test)
nb_accuracy = accuracy_score(y_test, nb_pred)
print("Naive Bayes Accuracy:", nb_accuracy)
# Out:
# Naive Bayes Accuracy: 0.9714285714285714

# %%
# Logistic Regression
logistic_reg = LogisticRegression(max_iter=1000)
logistic_reg.fit(X_train, y_train)
logistic_pred = logistic_reg.predict(X_test)
logistic_accuracy = accuracy_score(y_test, logistic_pred)
print("Logistic Regression Accuracy:", logistic_accuracy)
# Out:
# Logistic Regression Accuracy: 0.9428571428571428

# %%
# Support Vector Classifier
from sklearn.svm import SVC

svm_classifier = SVC()
svm_classifier.fit(X_train, y_train)
svm_pred = svm_classifier.predict(X_test)
svm_accuracy = accuracy_score(y_test, svm_pred)
print(f"Support Vector Machine Accuracy:{ svm_accuracy*100:.2f}%")
# Out:
# Support Vector Machine Accuracy:97.14%

# %%
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(X_train,y_train)
y_pred=lr.predict(X_test)
accuracy_lr=accuracy_score(y_test,y_pred)
print(f"Accuracy of logisticRegresssion is  {accuracy_lr*100:.2f}%")
# Out:
# Accuracy of logisticRegresssion is  94.29%
